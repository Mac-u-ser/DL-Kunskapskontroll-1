# %% [markdown]
# # Pretrained Models - Kunskapskontroll

# %% [markdown]
# **Obligatoriskt att fylla i uppgifterna nedan.**
#
# Namn: Anton Grigoriev
#
# Vem du har presenterat för: Daniel B., Parsan och Abdulrahman
#
# Datum då du presenterade: 240508
#
# **Kunskapskontrollen lämnas in på Omniway.**

# %% [markdown]
# **It is possible to load pretrained models which is a powerful concept.**

# %% [markdown]
# Model implementation:
# https://keras.io/api/applications/#usage-examples-for-image-classification-models
#
# Class list for ResNet50, for example tennis ball is 852:
# https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
# Out:
# 2024-05-05 13:02:14.490971: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = ResNet50(weights='imagenet')
# Out:
# 2024-05-05 13:23:11.221203: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
# 102967424/102967424 [==============================] - 12s 0us/step

# %%
img_path = 'zebra.jpg'
# img_path = 'linjal.jpg'
# img_path = 'tennisboll.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/preprocess_input
x = preprocess_input(x)

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# 1/1 [==============================] - 0s 133ms/step
# Predicted: [('n02391049', 'zebra', 0.98642665), ('n02423022', 'gazelle', 0.003437706), ('n01798484', 'prairie_chicken', 0.002941287)]

# %% [markdown]
# # 1. Take some pictures yourself and predict their class.

# %%
img_path = 'smutsig mått.JPG'
img = image.load_img(img_path, target_size=(224, 224))
display(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
print(x.shape)
x = preprocess_input(x)
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
# (1, 224, 224, 3)
# 1/1 [==============================] - 0s 119ms/step
# Predicted: [('n03400231', 'frying_pan', 0.5055012), ('n03633091', 'ladle', 0.26572707), ('n03733805', 'measuring_cup', 0.13679957)]

# %%
img_path = 'hushålspapper.JPG'
img = image.load_img(img_path, target_size=(224, 224))
display(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
print(x.shape)
x = preprocess_input(x)
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
# (1, 224, 224, 3)
# 1/1 [==============================] - 0s 119ms/step
# Predicted: [('n15075141', 'toilet_tissue', 0.80901307), ('n03887697', 'paper_towel', 0.15398419), ('n03786901', 'mortar', 0.0062698144)]

# %%
img_path = 'äpple.JPG'
img = image.load_img(img_path, target_size=(224, 224))
display(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
print(x.shape)
x = preprocess_input(x)
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
# (1, 224, 224, 3)
# 1/1 [==============================] - 0s 124ms/step
# Predicted: [('n07734744', 'mushroom', 0.31324401), ('n03804744', 'nail', 0.1997944), ('n13054560', 'bolete', 0.067274235)]

# %%
img_path = 'äpple2.JPG'
img = image.load_img(img_path, target_size=(224, 224))
display(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
print(x.shape)
x = preprocess_input(x)
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
# (1, 224, 224, 3)
# 1/1 [==============================] - 0s 132ms/step
# Predicted: [('n07615774', 'ice_lolly', 0.46299472), ('n07745940', 'strawberry', 0.25967318), ('n03729826', 'matchstick', 0.052904934)]

# %% [markdown]
# Ice lolly = https://en.wikipedia.org/wiki/Ice_pop

# %%
img_path = 'äpple3.JPG'
img = image.load_img(img_path, target_size=(224, 224))
display(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
print(x.shape)
x = preprocess_input(x)
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
# (1, 224, 224, 3)
# 1/1 [==============================] - 0s 129ms/step
# Predicted: [('n03476684', 'hair_slide', 0.24387585), ('n07745940', 'strawberry', 0.16944434), ('n03729826', 'matchstick', 0.122543946)]

# %% [markdown]
# ## slutsats:
# Äpple verkar inte finnas med i träningsdatabasen (jag läste fel). Annars gissar modellen otroligt bra!

# %% [markdown]
# # 2. Answer the question: Why is "Pretrained models" a very powerful concept?

# %% [markdown]
# Pretrained models are trained on large datasets for a long time, and can be very deep with many hidden layers:

# %%
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
# ...

# %% [markdown]
# I was able in 5 mins identify sample images - **it can save resources and time**.
